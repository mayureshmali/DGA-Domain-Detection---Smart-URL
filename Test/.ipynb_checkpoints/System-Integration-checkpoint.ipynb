# %%
# !pip install tldextract
# Out:
# Requirement already satisfied: tldextract in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.2.2)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tldextract) (2.6)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tldextract) (39.1.0)
# Requirement already satisfied: requests-file>=1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tldextract) (1.5.1)
# Requirement already satisfied: requests>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tldextract) (2.20.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests-file>=1.4->tldextract) (1.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.1.0->tldextract) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.1.0->tldextract) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.1.0->tldextract) (1.23)
# You are using pip version 10.0.1, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import boto3
import json
import time
import tldextract
from pprint import pprint

# %%
def predict_one_dga_value(sm_client, features, endpoint_name):
    # print('Using model endpoint {} to predict dga for this feature vector: {}'.format(endpoint_name, features))
    is_dga = False
    body = features + '\n'
    start_time = time.time()

    response = sm_client.invoke_endpoint(
                        EndpointName=endpoint_name,
                        ContentType='text/csv',
                        Body=body)
    predicted_value = json.loads(response['Body'].read())
    duration = time.time() - start_time
    if predicted_value > 0.5:
        is_dga = True
    return is_dga

# %%
VALID_CHARS = 'abcdefghijklmnopqrstuvwxyz0123456789-_'
LOOKUP_TABLE = None

def encode_fqdn(fqdn='www.google.com'):
    global VALID_CHARS
    global LOOKUP_TABLE
    if not LOOKUP_TABLE:
        LOOKUP_TABLE = dict()
        idx = 1
        for c in VALID_CHARS:
            LOOKUP_TABLE[c] = int(idx)
            idx += int(1)
            
    ds = tldextract.extract(fqdn)
    domain = ds.domain
    rvalue = list()
    for c in domain:
        rvalue.append(str(LOOKUP_TABLE[c]))
    for _ in range(len(rvalue), 63):
        rvalue.append('0')
    return ','.join(rvalue)

# %%
runtime_sm_client = boto3.client(service_name='sagemaker-runtime')
right = float(0)
wrong = float(0)
with open('assignment.csv', mode='r', encoding='utf-8') as ih:
    line = ih.readline()
    while True:
        line = ih.readline()
        if line == '':
            break
        tokens = line.split(',')
        domain = tokens[0]
        threat = tokens[1]
        domain = domain.lstrip().rstrip().lower()
        threat = threat.lstrip().rstrip().lower()
        features = encode_fqdn(fqdn=domain)
        p = predict_one_dga_value(sm_client=runtime_sm_client, features=features, endpoint_name='dga-endpoint-0')
        if p == True:
            print(domain + ', dga')
        else:
            print(domain + ', benign')
        
        if (p == True and threat == 'dga') or (p == False and threat == 'benign'):
            right += 1.0
        else:
            wrong += 1.0
            
print('Right: ', right, ' Wrong: ', wrong, 'Score: ', (right / (right + wrong)) * 100.0)
# Out:
# www.dutchwebdesign.com, benign
# www.pploulsosohvmkv.com, dga
# www.cfsjdqwdhmwkiv.com, dga
# www.uocoqgiusyeciouaimcauykqswsymo.com, dga
# www.total-toolbar.com, benign
# www.australianwoodenboatfestival.com, benign
# www.okdbnxoauhzrawyu.com, dga
# www.409485.com, benign
# www.m8sdetc0u81lgdcpshoxsvy.com, dga
# www.qkdccn.com, dga
# www.bangsfamilydentistry.com, benign
# www.g2g0kfwnw65lqri.com, dga
# www.rukketsports.com, benign
# www.eayprkbngtpgmoi.com, benign
# www.mobiuslifesciences.com, benign
# www.rpipmaed.com, benign
# www.vokalrausch.com, benign
# www.heekifxmnyc.com, dga
# www.amityprinting.com, benign
# www.puertoricotkd.com, benign
# www.vglaczv.com, dga
# www.zxseball.com, dga
# www.luzern.com, benign
# www.aaeqmogiqwacy.com, dga
# www.omomgqlexxcpxh.com, dga
# www.89597.com, benign
# www.walkerpestmanagement.com, benign
# www.plasticlabel.com, benign
# www.gymodhockey.com, dga
# www.rsnaxplccl.com, dga
# www.rajajasti.com, benign
# www.ckisrancisco.com, dga
# www.vnkhiolaq.com, dga
# www.quadcopterlounge.com, benign
# www.trilbytour.com, benign
# www.kf56uns6q2q8w2af7la.com, dga
# www.258639.com, benign
# www.mymewasm.com, dga
# www.kuuaacowgwqqsquesouewewqogcck.com, dga
# www.orgt5lw2kjqvs0ex3f7tad5.com, dga
# www.voicesofculture.com, benign
# www.365bongda.com, benign
# www.425480.com, benign
# www.ejjkmouvokoad.com, dga
# www.hokmirmlrjpo.com, dga
# www.ndokstring.com, dga
# www.comeonbaby.com, benign
# www.opw6sjg6ur5pc6c.com, dga
# www.ghoned3ngh3vwd1tgt3.com, dga
# www.bhnfikbvtj.com, dga
# www.amneville.com, benign
# www.evbnktl.com, dga
# www.abw-ang.com, benign
# www.207256.com, benign
# www.kukogaoia.com, benign
# www.twfsswdup.com, dga
# www.dpnmareisbad.com, dga
# www.7525.com, benign
# www.bgkkvvyxurvu.com, dga
# www.karameltadinda.com, benign
# www.wdsqjjormqx.com, dga
# www.homeeducationresources.com, benign
# www.rumahtheme.com, benign
# www.aaf-fd.com, benign
# www.1ywssal1glrez1109g2i1kiz0l.com, dga
# www.iha23di85xgv74ify4i.com, dga
# www.ulvloosk.com, dga
# www.ieeroemazhexwphipxrtcmgbr.com, benign
# www.ocmkcqykokwyawgcwwwqgeuumw.com, dga
# www.ocgygeumgeoyesycmgsciieyewasgyc.com, dga
# www.ewec2010.com, benign
# www.hseivhcsalv.com, dga
# www.mycywguaaks.com, dga
# www.conceptum-sport-logistics.com, benign
# www.tlonptwrbog.com, dga
# www.gyiomachuslazaroqok.com, dga
# www.discoveringthekootenays.com, benign
# www.huomie.com, benign
# www.myeyuwaskkqqeyusiwuegiqwysiye.com, dga
# www.qgmsgmeeguccmsiewqo.com, dga
# www.exybwxgfe0olcbm.com, dga
# www.acortalo.com, benign
# www.eatpizzaq.com, dga
# www.kuwmaamcwucyciquecy.com, dga
# www.devicon.com, benign
# www.twistedgroove.com, benign
# www.292263.com, benign
# www.radioprimetime.com, benign
# www.kyoman.com, benign
# www.vofypyfofuv.com, dga
# www.qgnysagabardinedazyx.com, dga
# www.arxnejast.com, benign
# www.wclringlane.com, dga
# www.antonopoulou-makeup.com, benign
# www.iqwuqeky.com, dga
# www.8517.com, benign
# www.tqzdalkdsh.com, dga
# www.fornits.com, benign
# www.aaogmyyi.com, dga
# www.genderflux.com, dga
# www.local33.com, benign
# www.easytogotacosgarcesfam.com, benign
# www.aiqhuowixyyl.com, dga
# www.lubqolddincmydvjmcg.com, dga
# www.qgcilane.com, dga
# www.mt4trader.com, benign
# www.airviewonline.com, benign
# www.1hedfs21cdqfcr1q3m26o1vgk0el.com, dga
# www.yuxgkandfield.com, dga
# www.halherzog.com, benign
# www.pkclick4u.com, dga
# www.hydroinformatics.com, benign
# www.cinemaescapist.com, benign
# www.postmediavfx.com, benign
# www.piubtjyfvkdrv.com, dga
# www.uhaicivsctmpkahok.com, dga
# www.stoneward.com, benign
# www.dendrocacalia.com, benign
# www.aagiuayykiueackciiuiec.com, dga
# www.o0q45bq6ej5lshs.com, dga
# www.oscgacivic.com, dga
# www.jometeo.com, benign
# www.bbqublxmlljeudbltgtbcxs.com, dga
# www.hgrfrjixwrkx.com, dga
# www.ibytzv.com, dga
# www.mironet.com, benign
# www.onvhopjnfajvlkfm.com, dga
# www.ndrrqxhayf.com, dga
# www.dechenlingashland.com, benign
# www.spmbrzqtmvfrbpxkzhjkf.com, dga
# www.qqebican765.com, dga
# www.kenbailey.com, benign
# www.gozoamentalistfanchonut.com, dga
# www.beckersdental.com, benign
# www.wisemann.com, benign
# www.amjqoki.com, dga
# www.swnranerraticallyqozaw.com, dga
# www.riversedgehorserescue.com, benign
# www.voicecallsguru.com, dga
# www.zekesaucedo.com, benign
# www.lplerfhzo.com, dga
# www.rdibkgmwiombjojtji.com, dga
# www.jjnxtv1wqx00l1f5d2ykynj7o8.com, dga
# www.wsecqecmaysggigakccie.com, dga
# www.spitzenwanderweg.com, benign
# www.morningfurniture.com, benign
# www.indianapresbyterian.com, benign
# www.gvi2gvc4mj7hex54sfw.com, dga
# www.xdrhfecukeqd.com, dga
# www.deercreekvineyards.com, benign
# www.floresarts.com, benign
# www.skiiiekuuyaoeiyeys.com, dga
# www.uosuueaycamy.com, dga
# www.sjakk.com, benign
# www.muktiorganics.com, benign
# www.khwaiter.com, benign
# www.cloecassandro.com, benign
# www.kthipijgpfar.com, dga
# www.karadatokeruspa.com, benign
# www.larryshankle.com, benign
# www.eisiwaksyukmqkmgmwwwo.com, dga
# www.72mena.com, benign
# www.mrslots.com, benign
# www.blackstonetheseries.com, benign
# www.wqvlepictom.com, dga
# www.electromicro.com, benign
# www.hacopoz.com, dga
# www.masslessness.com, benign
# www.mlazyc.com, benign
# www.o0uhsdsneja2stufgtm.com, dga
# www.cubeaonlwkj.com, dga
# www.employee-scheduling.com, benign
# www.umpknta.com, dga
# www.237208.com, benign
# www.cssclass.com, benign
# www.iboplus.com, benign
# www.qxwcpcuaehuwbqjznmdsb.com, dga
# www.hyqmwolmcdxn.com, dga
# www.1mh3e3n16jrg09slhquijblphq.com, dga
# www.chaosradio.com, benign
# www.melfordf150.com, dga
# www.medastsc.com, benign
# www.jlmdtaprius.com, dga
# www.1tl1lovqeyf5rwdht2412xycdt.com, dga
# www.pranavashram.com, benign
# www.1gb6mo41s01tridbbmtq11zby8k.com, dga
# www.doqotosifoziheryga.com, dga
# www.142176.com, benign
# www.pqacrang.com, dga
# www.s1g1b15onm.com, benign
# www.vlhsengerjet.com, dga
# www.njtement.com, dga
# www.emacu.com, benign
# www.qverwfk0cfkx5l32oxgbgvq.com, dga
# www.syghtglassesshop.com, benign
# www.rytapaqycehe.com, dga
# www.odkbgvs2qjy6mjehinmnwty.com, dga
# www.qamsacivic.com, dga
# www.katumoto.com, benign
# www.mcfrsolbksninpt.com, dga
# www.aardvarkfilm.com, dga
# www.dxwgyg.com, dga
# www.viulapoesia.com, benign
# www.tallboysapparel.com, benign
# www.dealgps.com, benign
# www.tomorrowindtoday.com, benign
# www.qgaoqymssugmgikciaew.com, dga
# www.zjosnocugfwt.com, dga
# www.n3rdsinsid3.com, benign
# www.studio-nahe.com, benign
# www.ryhefogigycaqyvybuhuh.com, dga
# www.kvuwevgeminefjy.com, dga
# www.1vq6hbiwywo9dimd4ie10hignl.com, dga
# www.lordjagannath.com, benign
# www.pmaqma1i3bsr11auta761c94v4c.com, dga
# www.u0yvc6ixmbibc85.com, dga
# www.galorubapetos.com, benign
# www.eco4649.com, benign
# www.mamamushi.com, benign
# www.gmyimmicqqci.com, dga
# www.aaimuowmaqowiuyekqaco.com, dga
# www.bereavementontarionetwork.com, benign
# www.dseafsfen.com, benign
# www.triumfo.com, benign
# www.telly.com, benign
# www.cxdn9217jotdy132avsn1vlxlax.com, dga
# www.shopandcare.com, benign
# www.chicpussy.com, benign
# www.venetofronteskinheads.com, benign
# www.jlelxyhpjxijxq.com, dga
# www.370031.com, benign
# www.gburgpsf.com, dga
# www.364616.com, benign
# www.cotondesoie.com, benign
# www.gjm8gtm4gh70adonu0y.com, dga
# www.aspo-tostero.com, benign
# www.phishreport.com, benign
# www.evergreensquash.com, benign
# www.ravemarket.com, benign
# www.lovenotesquartet.com, benign
# www.ol5xgta6epef1ncl3d3tw4c.com, dga
# www.stevecomisar.com, benign
# www.10ksa.com, benign
# www.logic-mi.com, benign
# www.amicitiaboukoul.com, benign
# www.uhjvlkfoixtcelo.com, dga
# www.91el07ij0nzt1jjlh6l5qjgtf.com, dga
# www.moss-bordered.com, benign
# www.publicsectorexecutive.com, benign
# www.sammystruckrepair.com, benign
# www.isfce.com, benign
# www.lkaerooclqrq.com, dga
# www.sousleground.com, benign
# www.anotherdayintheempire.com, benign
# www.enbridgeincomefund.com, benign
# www.vtrpotwfkapasmgdi.com, dga
# www.434423.com, benign
# www.u23lib5bcxw0yju.com, dga
# www.prmysangh.com, dga
# www.ociqkeasqocgoecksu.com, dga
# www.hj-9.com, benign
# www.fpa-be.com, benign
# Right:  419.0  Wrong:  81.0 Score:  83.8
